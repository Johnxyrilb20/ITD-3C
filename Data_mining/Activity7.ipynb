# %% [markdown]
# <h1> <b> Analysis: </b>John Xyril B. Cabana</h1>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import folium
import matplotlib.pyplot as plt

# %% [markdown]
# <h1>Filtering</h1>

# %%
filter1=terrorist[terrorist['region_txt']== 'Middle East & North Africa']

# %%
filter2= filter1[filter1['attacktype1_txt'] == 'Bombing/Explosion']

# %%
filter3= filter2[filter2['nkill'] >= 10 ]

# %%
filter4= filter3[filter3['iyear'] >= 2000]

# %% [markdown]
# <h1>Data Aggregation</h1>

# %%
ME_terror = filter4.groupby(['longitude', 'latitude']).size().reset_index(name= 'incident_count')

# %%
ME_terror
# Out:
#      longitude   latitude  incident_count
# 0    -8.000000  31.633333               1
# 1    -7.610000  33.590000               1
# 2     0.138188  35.391899               1
# 3     1.988153  36.072919               1
# 4     2.344489  36.526708               1
# ..         ...        ...             ...
# 517  50.004524  26.554785               1
# 518  51.405190  35.724533               1
# 519  52.583610  29.591325               1
# 520  60.862701  29.483576               3
# 521  61.753754  26.079255               1
#
# [522 rows x 3 columns]

# %% [markdown]
# <h1>Geospatial visualization</h1>

# %%
import folium
from folium.plugins import HeatMap

# %%
heat_df = ME_terror[['latitude', 'longitude', 'incident_count']].values.tolist()

# %%
map_= folium.Map(location= [30,40], zoom_start = 4)

# %%
HeatMap(heat_df).add_to(map_)

# %% [markdown]
# <h1>Insight 1:</h1>
# <h2><b>Regional Analysis on Middle East</b>
#
# The attacks predominantly targeted locations frequented by Westerners, such as residential compounds, hotels, and tourist resorts, indicating a strategic focus on foreign nationals and symbols of Western presence. Al-Qaeda and its regional affiliates were responsible for several of these attacks, reflecting the organization's operational reach and influence across the Middle East during this period. The use of suicide bombings and coordinated attacks was a common tactic, aiming to maximize casualties and media impact. These attacks had significant repercussions on the host countries' security policies, economies—particularly tourism—and international relations, prompting increased counter-terrorism measures and cooperation with global partners.</h2>

# %%
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_19eb686a7916956cb8eb710071132707 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_19eb686a7916956cb8eb710071132707&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_19eb686a7916956cb8eb710071132707 = L.map(
#                 &quot;map_19eb686a7916956cb8eb710071132707&quot;,
#                 {
#                     center: [30.0, 40.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9b30814089556a0f6c183f9906b34a8f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9b30814089556a0f6c183f9906b34a8f.addTo(map_19eb686a7916956cb8eb710071132707);
#
#
#             var heat_map_5272c7c291556e7857c09ce3cf9e45bd = L.heatLayer(
#                 [[31.633333, -8.0, 1.0], [33.59, -7.61, 1.0], [35.391899, 0.138188, 1.0], [36.072919, 1.988153, 1.0], [36.526708, 2.344489, 1.0], [36.46298, 2.81464, 1.0], [36.763763, 3.055413, 3.0], [36.56522, 3.153934, 1.0], [36.562222, 3.594444, 2.0], [36.72398, 3.670848, 2.0], [36.672703, 3.809529, 1.0], [36.919552, 3.891396, 1.0], [36.37489, 3.902, 2.0], [36.716365, 4.049834, 1.0], [34.680833, 4.096944, 1.0], [36.077754, 4.462888, 1.0], [36.28611, 5.60722, 1.0], [36.813267, 5.751706, 1.0], [35.59901, 5.893085, 1.0], [35.55, 6.166667, 1.0], [36.673926, 6.83876, 1.0], [36.866618, 6.900388, 1.0], [35.43811, 7.146648, 1.0], [36.811427, 10.184214, 1.0], [33.819136, 10.855024, 1.0], [32.063988, 12.691492, 1.0], [32.8, 12.9, 1.0], [32.867867, 13.189067, 4.0], [32.407892, 14.622688, 1.0], [31.448914, 15.256008, 1.0], [31.395836, 15.724736, 1.0], [31.197586, 16.586681, 2.0], [32.069286, 20.151144, 7.0], [32.094952, 20.268871, 1.0], [32.42202, 20.451099, 1.0], [32.762238, 22.241188, 2.0], [27.058452, 27.969925, 1.0], [41.106178, 28.689863, 10.0], [30.762296, 29.696268, 1.0], [31.19829, 29.899403, 1.0], [30.787678, 30.999529, 1.0], [30.022924, 31.185192, 1.0], [30.084629, 31.334314, 2.0], [29.831976, 31.337257, 1.0], [31.039309, 31.379664, 1.0], [39.930771, 32.76754, 3.0], [39.798509, 32.805613, 1.0], [31.016779, 33.008587, 1.0], [30.608472, 33.617577, 1.0], [31.080795, 33.638188, 1.0], [30.699335, 33.644714, 1.0], [31.126646, 33.800865, 5.0], [30.886219, 34.076081, 1.0], [31.211645, 34.110425, 1.0], [31.212225, 34.117065, 3.0], [30.169854, 34.173178, 1.0], [31.250196, 34.24128, 1.0], [30.99614, 34.247173, 1.0], [27.915557, 34.329886, 1.0], [28.509136, 34.513634, 1.0], [31.821444, 34.665169, 1.0], [31.970541, 34.791725, 1.0], [32.08297, 34.811886, 3.0], [32.332612, 34.851529, 1.0], [32.325073, 34.854663, 1.0], [29.490095, 34.899447, 1.0], [32.473605, 34.975094, 1.0], [32.793921, 34.990615, 6.0], [32.161864, 35.137217, 1.0], [32.581387, 35.182465, 1.0], [31.771599, 35.2034, 9.0], [38.720489, 35.482597, 1.0], [33.861984, 35.489986, 2.0], [33.843471, 35.498738, 2.0], [33.888523, 35.503513, 3.0], [35.528404, 35.79232, 3.0], [33.126944, 35.825796, 1.0], [33.280891, 35.829319, 1.0], [34.438062, 35.830744, 2.0], [34.438094, 35.830837, 2.0], [34.443955, 35.854032, 1.0], [34.896351, 35.886443, 2.0], [34.896112, 35.886553, 1.0], [34.895928, 35.886652, 2.0], [35.361572, 35.927155, 4.0], [31.950001, 35.933331, 3.0], [32.835648, 35.970169, 1.0], [32.711067, 36.026836, 1.0], [32.674366, 36.056892, 1.0], [32.962402, 36.076488, 1.0], [33.436207, 36.080795, 1.0], [32.622334, 36.103756, 3.0], [33.622993, 36.11203, 1.0], [35.688751, 36.135868, 1.0], [32.834137, 36.156742, 1.0], [34.715336, 36.255295, 1.0], [33.484396, 36.268508, 1.0], [33.515244, 36.292084, 34.0], [33.435532, 36.295208, 1.0], [33.5111, 36.3064, 1.0], [33.60722, 36.314327, 1.0], [32.568889, 36.315278, 1.0], [35.813396, 36.319939, 1.0], [35.413296, 36.33012, 1.0], [33.446476, 36.334499, 6.0], [35.290483, 36.345111, 1.0], [33.488998, 36.346882, 4.0], [33.561504, 36.368763, 2.0], [33.484444, 36.377289, 1.0], [33.755295, 36.388622, 1.0], [33.527649, 36.392296, 1.0], [32.696985, 36.398428, 1.0], [35.713863, 36.525666, 1.0], [36.264221, 36.565708, 3.0], [32.709763, 36.567642, 1.0], [34.951523, 36.581963, 1.0], [35.813972, 36.609917, 2.0], [35.928802, 36.631451, 5.0], [35.933333, 36.633333, 1.0], [35.925894, 36.6519, 1.0], [36.313854, 36.660312, 1.0], [35.855245, 36.671186, 1.0], [36.01313, 36.673443, 1.0], [35.647797, 36.675259, 2.0], [35.990086, 36.677223, 1.0], [36.310444, 36.689156, 3.0], [33.6432, 36.690445, 1.0], [35.982761, 36.704647, 2.0], [34.717705, 36.722824, 21.0], [33.611455, 36.75523, 1.0], [35.129181, 36.760738, 2.0], [36.213078, 36.769512, 1.0], [34.097931, 36.770164, 1.0], [35.868511, 36.804665, 1.0], [35.068056, 36.888889, 1.0], [36.377281, 36.993607, 1.0], [35.993954, 36.998383,

# %% [markdown]
# <h1>Insight 2:</h1>
# <h2><b>Regional Analysis on SouthEast Asia</b>
#
# Since 2000, Southeast Asia has experienced significant terrorist activity, especially in the Philippines, which has faced persistent threats from groups like Abu Sayyaf, Jemaah Islamiyah, and the Moro Islamic Liberation Front. Notable attacks include the 2002 Zamboanga City bombings, the 2003 Davao City airport bombing, and the Davao ferry terminal bombing, each causing over 10 fatalities. These groups often target public spaces and symbols of government authority, aiming to create fear and gain media attention.
# <h3>Terrorist tactics have evolved with a troubling increase in suicide bombers, including women and children, as seen in the 2018 Surabaya church bombings. In response, both Indonesia and the Philippines have strengthened their counterterrorism efforts through specialized military units and new legal frameworks, though challenges remain due to regional instability and insurgency.</h3></h2>

# %%
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ef0db276f5ea3d3478f7575ce50ce125 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ef0db276f5ea3d3478f7575ce50ce125&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ef0db276f5ea3d3478f7575ce50ce125 = L.map(
#                 &quot;map_ef0db276f5ea3d3478f7575ce50ce125&quot;,
#                 {
#                     center: [30.0, 40.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eccddd3cb7a0dac58b5e7d315e28b27a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eccddd3cb7a0dac58b5e7d315e28b27a.addTo(map_ef0db276f5ea3d3478f7575ce50ce125);
#
#
#             var heat_map_043e1f4e2ff2488066c8748e7f7a60c2 = L.heatLayer(
#                 [[20.816667, 92.366667, 1.0], [20.755581, 92.528722, 1.0], [4.962522, 97.752371, 1.0], [22.036199, 98.133856, 1.0], [20.431944, 98.165, 1.0], [16.687778, 98.508333, 1.0], [23.830851, 98.538749, 1.0], [23.694157, 98.769736, 1.0], [23.693281, 98.772316, 2.0], [21.291422, 99.606854, 1.0], [7.001944, 100.457222, 1.0], [13.785793, 100.560852, 1.0], [6.477408, 101.135293, 1.0], [6.545499, 101.2799, 1.0], [6.548956, 101.638533, 1.0], [6.210408, 101.820757, 1.0], [18.932214, 102.449384, 1.0], [-6.208821, 106.846046, 3.0], [-8.790422, 115.159278, 1.0], [-8.722791, 115.17229, 3.0], [-1.763255, 120.640908, 2.0], [16.9925, 120.734228, 1.0], [13.013408, 120.761778, 1.0], [14.601285, 120.952293, 1.0], [16.701617, 120.974655, 1.0], [14.599352, 120.984772, 1.0], [6.05519, 121.001323, 1.0], [6.077377, 121.082137, 1.0], [5.933025, 121.100058, 1.0], [13.173328, 121.277093, 1.0], [16.670038, 121.71723, 1.0], [17.126104, 122.008131, 1.0], [6.929089, 122.07885, 1.0], [6.645556, 122.101944, 1.0], [6.497216, 122.105141, 1.0], [14.031391, 122.113091, 1.0], [6.501935, 122.123761, 1.0], [7.708474, 122.140274, 1.0], [7.8105, 122.145358, 1.0], [6.473787, 122.163853, 1.0], [6.644421, 122.273133, 1.0], [7.806878, 122.701145, 1.0], [8.588406, 123.33978, 1.0], [12.21814, 123.50951, 1.0], [8.115408, 123.896522, 1.0], [9.860086, 124.007877, 1.0], [7.840063, 124.020195, 1.0], [8.020031, 124.056593, 1.0], [8.182602, 124.114554, 1.0], [7.860251, 124.130054, 1.0], [7.51611, 124.25639, 1.0], [7.374077, 124.266678, 1.0], [6.898558, 124.476696, 1.0], [7.029702, 124.500663, 1.0], [7.742853, 124.70475, 1.0], [7.199509, 124.796982, 1.0], [6.497656, 124.849655, 1.0], [7.084194, 124.900047, 1.0], [-9.492408, 124.955521, 1.0], [7.762916, 125.005822, 1.0], [6.11622, 125.169395, 2.0], [12.1406, 125.4397, 1.0], [7.083241, 125.600998, 3.0], [9.073155, 125.89024, 1.0], [8.6, 125.916667, 1.0], [7.869039, 126.374112, 1.0], [-3.688889, 128.186389, 1.0], [-3.341638, 128.352878, 1.0], [-3.721569, 138.060511, 1.0]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_043e1f4e2ff2488066c8748e7f7a60c2.addTo(map_ef0db276f5ea3d3478f7575ce50ce125);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
filter1=terrorist[terrorist['region_txt']== 'Southeast Asia']
filter2= filter1[filter1['iyear'] >= 2000]
filter3= filter2[filter2['nkill'] >= 10 ]

# %%
ME_terror = filter3.groupby(['longitude', 'latitude']).size().reset_index(name= 'incident_count')

# %%
heat_df = ME_terror[['latitude', 'longitude', 'incident_count']].values.tolist()
map_= folium.Map(location= [30,40], zoom_start = 4)
HeatMap(heat_df).add_to(map_)

# %% [markdown]
# <h1>Insight 3:</h1>
# <h2><b>Regional Analysis on North America</b>
#
# In New York City, the most significant terrorist attack since 2000 remains the September 11, 2001 attacks, where al-Qaeda operatives hijacked two planes and crashed them into the World Trade Center towers, resulting in 2,977 fatalities. This event stands as the deadliest terrorist attack in world history. Since then, New York has experienced other terrorist incidents, but none have resulted in more than 10 fatalities. Notably, the October 31, 2017 truck attack in Lower Manhattan, carried out by Sayfullo Saipov, resulted in eight deaths and 12 injuries. This attack was the deadliest in New York City since 9/11. Other incidents, such as the 2016 Chelsea bombing and the 2022 Brooklyn subway shooting, caused multiple injuries but did not result in fatalities exceeding 10. The 2015 San Bernardino attack stands out as a major terrorist incident in North America post-2000, where two attackers carried out a mass shooting and attempted bombing during a county employee event, killing 14 people—marking it as a significant act of Islamic terrorism in California.</h2>

# %%
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_53ebedd1e93d39ed0365f706d91b252d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_53ebedd1e93d39ed0365f706d91b252d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_53ebedd1e93d39ed0365f706d91b252d = L.map(
#                 &quot;map_53ebedd1e93d39ed0365f706d91b252d&quot;,
#                 {
#                     center: [30.0, 40.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3b3e90280de610ebd469c4e38f1001eb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3b3e90280de610ebd469c4e38f1001eb.addTo(map_53ebedd1e93d39ed0365f706d91b252d);
#
#
#             var heat_map_48106d6615d2d3de8b870e0b0dae3f70 = L.heatLayer(
#                 [[43.288981, -123.333302, 1.0], [34.07577, -117.277924, 1.0], [36.082645, -115.135925, 1.0], [24.413892, -106.727641, 1.0], [25.673211, -100.309201, 1.0], [19.371887, -99.086624, 1.0], [31.13, -97.78, 1.0], [31.816677, -97.087902, 1.0], [28.519601, -81.376794, 1.0], [40.018464, -78.907197, 1.0], [38.878742, -77.100006, 1.0], [40.697132, -73.931351, 2.0]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_48106d6615d2d3de8b870e0b0dae3f70.addTo(map_53ebedd1e93d39ed0365f706d91b252d);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
filter1=terrorist[terrorist['region_txt']== 'North America']
filter2= filter1[filter1['iyear'] >= 2000]
filter3= filter2[filter2['nkill'] >= 10 ]

# %%
ME_terror = filter3.groupby(['longitude', 'latitude']).size().reset_index(name= 'incident_count')

# %%
heat_df = ME_terror[['latitude', 'longitude', 'incident_count']].values.tolist()
map_= folium.Map(location= [30,40], zoom_start = 4)
HeatMap(heat_df).add_to(map_)

# %% [markdown]
# <h1>Insight 4:</h1>
# <h2><b>Regional Analysis on Australasia & Oceania</b>
#
# Since 2000, there have been several significant violent incidents in Papua New Guinea (PNG), particularly in its northern regions, including New Guinea, New Ireland, and Port Moresby. In February 2024, a massacre in Enga Province resulted in at least 26 deaths, with some reports indicating up to 49 fatalities, due to a tribal conflict involving firearms such as M16s and AR15s . In July 2024, a gang killed at least 26 villagers across three remote villages in northern PNG, with eight others reported missing, amid disputes over land ownership and accusations of sorcery . Additionally, in 1996, a shooting incident at Timika Airport in Papua Province, Indonesia, resulted in 16 deaths, including five Indonesian soldiers and a New Zealand pilot . These events highlight ongoing intertribal violence and social tensions in the region, often exacerbated by disputes over resources and cultural practices.</h2>

# %%
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_70ba466018e8cdc0d1a502108bb86d04 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_70ba466018e8cdc0d1a502108bb86d04&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_70ba466018e8cdc0d1a502108bb86d04 = L.map(
#                 &quot;map_70ba466018e8cdc0d1a502108bb86d04&quot;,
#                 {
#                     center: [30.0, 40.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_07784fc87e538652e877c15f257ee05d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_07784fc87e538652e877c15f257ee05d.addTo(map_70ba466018e8cdc0d1a502108bb86d04);
#
#
#             var heat_map_476e6e2abdc2475ba4f4f3ba7a56a727 = L.heatLayer(
#                 [[-31.743357, 115.764172, 2.0], [-31.952854, 115.857339, 1.0], [-31.959414, 115.873955, 1.0], [-32.053696, 115.960731, 1.0], [-6.127153, 143.420306, 1.0], [-5.492729, 143.7241, 1.0], [-38.047645, 144.170032, 1.0], [-6.066667, 144.25, 1.0], [-38.133743, 144.333937, 1.0], [-38.138255, 144.348328, 1.0], [-38.094181, 144.3571, 1.0], [-38.091417, 144.357575, 1.0], [-5.782101, 144.642348, 1.0], [-37.808896, 144.950421, 1.0], [-37.813187, 144.96298, 1.0], [-37.814107, 144.96328, 1.0], [-37.698082, 144.964664, 1.0], [-37.8182, 144.965, 1.0], [-37.698179, 144.965079, 1.0], [-37.698036, 144.965437, 1.0], [-37.898215, 144.995554, 1.0], [-37.858684, 144.996338, 1.0], [-37.906633, 145.007628, 1.0], [-37.789922, 145.170775, 1.0], [-37.988975, 145.217452, 1.0], [-36.35772, 146.696395, 1.0], [-9.441944, 147.218889, 1.0], [-42.884049, 147.323719, 1.0], [-6.604156, 147.852361, 1.0], [-6.598434, 147.853302, 3.0], [-33.283013, 149.100151, 2.0], [-35.349304, 149.244385, 1.0], [-33.694586, 149.328405, 1.0], [-33.704174, 149.857408, 1.0], [-2.578117, 150.808608, 1.0], [-34.031804, 150.850332, 1.0], [-33.815128, 151.003155, 1.0], [-33.815129, 151.003278, 1.0], [-33.922832, 151.011897, 1.0], [-33.907092, 151.057308, 1.0], [-33.724162, 151.085374, 1.0], [-33.829658, 151.117538, 1.0], [-33.934491, 151.179691, 1.0], [-33.867979, 151.211038, 1.0], [-33.888408, 151.237218, 2.0], [-27.661735, 151.897583, 1.0], [-27.581562, 151.933834, 1.0], [-27.564238, 151.947275, 1.0], [-27.470933, 153.023502, 1.0], [-27.639793, 153.108516, 1.0], [-28.0291, 153.431388, 1.0], [-9.584336, 160.155603, 2.0], [-8.766667, 160.7, 1.0], [-36.84846, 174.763332, 1.0], [-41.28646, 174.776236, 8.0], [-41.124433, 175.070783, 1.0], [-37.957009, 176.986756, 1.0], [-17.624167, 177.452778, 1.0], [-18.1416, 178.4419, 2.0], [-16.779911, 179.33811, 1.0], [-16.433333, 179.366667, 1.0]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_476e6e2abdc2475ba4f4f3ba7a56a727.addTo(map_70ba466018e8cdc0d1a502108bb86d04);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
filter1=terrorist[terrorist['region_txt']== 'Australasia & Oceania']
filter2= filter1[filter1['iyear'] >= 2000]
ME_terror = filter2.groupby(['longitude', 'latitude']).size().reset_index(name= 'incident_count')
heat_df = ME_terror[['latitude', 'longitude', 'incident_count']].values.tolist()
map_= folium.Map(location= [30,40], zoom_start = 4)
HeatMap(heat_df).add_to(map_)

# %% [markdown]
# <h1>Insight 5:</h1>
# <h2><b>Regional Analysis on Central Asia</b>
#
# Since 2000, Central Asia has experienced several significant terrorist incidents resulting in over 10 fatalities, often linked to Islamist extremist groups. In 2004, the Islamic Jihad Union orchestrated suicide bombings in Tashkent, targeting the U.S. and Israeli embassies, and the prosecutor's office, causing multiple deaths and injuries. The Andijan massacre in 2005 saw Uzbek security forces kill between 187 and 1,500 protesters, amid unrest allegedly involving groups like the Islamic Movement of Uzbekistan (IMU) and Hizb ut-Tahrir. Kazakhstan's 2016 Aktobe shootings involved militants robbing gun shops and attacking a National Guard base, resulting in at least 18 deaths. Additionally, the rise of the Islamic State's Afghan affiliate, IS-K, has led to increased recruitment from Central Asia, including Tajikistan, with nationals involved in attacks in Russia and Europe. These events underscore the region's vulnerability to transnational terrorism, driven by a mix of ideological extremism, political repression, and regional instability.</h2>

# %%
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2541798742a605aabb807f7d08416e5f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2541798742a605aabb807f7d08416e5f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2541798742a605aabb807f7d08416e5f = L.map(
#                 &quot;map_2541798742a605aabb807f7d08416e5f&quot;,
#                 {
#                     center: [30.0, 40.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_890788b4b9ffc832e1be72bbb0df336b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_890788b4b9ffc832e1be72bbb0df336b.addTo(map_2541798742a605aabb807f7d08416e5f);
#
#
#             var heat_map_7cfc7d1e037fa8ae13566e0dbdc33391 = L.heatLayer(
#                 [[28.291564, -16.62913, 1.0], [43.309109, 40.253819, 2.0], [43.100215, 40.63256, 2.0], [43.00732, 40.989151, 7.0], [43.000001, 41.010325, 1.0], [43.001525, 41.023415, 1.0], [43.160179, 41.347215, 1.0], [42.973782, 41.44218, 2.0], [42.711201, 41.461609, 1.0], [43.033102, 41.481171, 1.0], [43.067126, 41.609606, 1.0], [42.426836, 41.62898, 1.0], [41.638643, 41.637265, 1.0], [42.68391, 41.63732, 1.0], [42.645873, 41.645188, 1.0], [42.640355, 41.671374, 1.0], [42.615404, 41.71987, 1.0], [42.628029, 41.735661, 4.0], [42.45083, 41.788319, 1.0], [42.581387, 41.806926, 1.0], [42.497582, 41.811052, 1.0], [42.542335, 41.851189, 2.0], [42.666912, 41.853264, 1.0], [42.502129, 41.86095, 1.0], [42.502066, 41.861007, 2.0], [42.646663, 41.914019, 1.0], [42.715902, 41.987861, 2.0], [42.268768, 42.061798, 1.0], [42.60503, 42.067112, 1.0], [42.521911, 42.127673, 1.0], [42.25, 42.7, 1.0], [41.675238, 43.035167, 1.0], [42.118292, 43.699484, 1.0], [42.165295, 43.773138, 1.0], [42.112836, 43.789602, 1.0], [42.157447, 43.87569, 1.0], [42.171052, 43.876073, 1.0], [42.331061, 43.934244, 1.0], [42.075694, 43.954046, 1.0], [42.167992, 43.957303, 1.0], [42.224159, 43.9632, 10.0], [40.661378, 43.971352, 1.0], [42.195426, 43.9785, 2.0], [42.203769, 43.990513, 3.0], [42.23, 44.002778, 1.0], [42.247802, 44.037438, 2.0], [42.271957, 44.038079, 1.0], [42.273016, 44.039621, 1.0], [42.346365, 44.049253, 1.0], [42.271213, 44.066878, 1.0], [42.507664, 44.076154, 1.0], [42.086989, 44.094577, 2.0], [41.985414, 44.108411, 1.0], [41.981361, 44.109539, 3.0], [42.169724, 44.110118, 1.0], [41.446525, 44.172998, 1.0], [42.115346, 44.24208, 1.0], [42.052387, 44.330282, 1.0], [41.927551, 44.411911, 1.0], [42.212463, 44.436139, 1.0], [40.807399, 44.497027, 1.0], [40.17857, 44.535763, 9.0], [41.715299, 44.782515, 1.0], [41.71706, 44.783022, 1.0], [41.716667, 44.783333, 1.0], [41.716715, 44.783361, 1.0], [41.709968, 44.792998, 1.0], [41.709981, 44.792998, 17.0], [41.541279, 45.027699, 1.0], [41.478303, 46.620167, 1.0], [41.633611, 46.643333, 3.0], [41.588928, 46.687849, 1.0], [39.829805, 46.759851, 1.0], [39.664728, 46.951067, 1.0], [40.788386, 48.152228, 1.0], [39.110373, 48.323249, 1.0], [41.359738, 48.512347, 1.0], [40.41724, 49.903461, 8.0], [51.232903, 51.367553, 1.0], [47.101631, 51.9133, 3.0], [50.291965, 57.210571, 5.0], [37.950197, 58.380223, 1.0], [36.839877, 64.459816, 1.0], [51.8, 68.333333, 1.0], [51.811871, 68.35643, 2.0], [37.790454, 68.667803, 1.0], [38.552185, 68.767441, 12.0], [37.836394, 68.780338, 1.0], [37.836301, 68.780456, 1.0], [38.562525, 69.016689, 1.0], [38.553056, 69.019722, 1.0], [41.266667, 69.216667, 5.0], [41.367161, 69.272486, 1.0], [53.283333, 69.383333, 1.0], [41.364635, 69.38687, 1.0], [40.283333, 69.633333, 1.0], [37.842354, 70.046287, 1.0], [39.634779, 70.269866, 2.0], [38.693725, 70.485717, 1.0], [40.116667, 70.633333, 1.0], [39.759819, 70.907124, 1.0], [42.9, 71.366667, 1.0], [37.486729, 71.549843, 2.0], [37.50011, 71.550606, 1.0], [37.944485, 71.557178, 1.0], [36.727742, 71.611447, 1.0], [40.133486, 72.160865, 1.0], [40.783333, 72.333333, 2.0], [40.53, 72.8, 2.0], [40.933154, 72.981488, 1.0], [40.927343, 72.986433, 1.0], [40.8, 73.0, 1.0], [42.881778, 74.522733, 1.0], [42.699727, 74.546328, 1.0], [42.874621, 74.569762, 1.0], [42.872324, 74.585796, 1.0], [42.870022, 74.587883, 7.0], [42.805036, 74.591735, 1.0], [42.874722, 74.612222, 3.0], [42.816259, 74.63668, 1.0], [42.83329, 75.283469, 1.0], [42.82383, 75.292488, 1.0], [42.460422, 76.176146, 1.0], [43.254697, 76.912617, 3.0], [43.255058, 76.912628, 2.0]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_7cfc7d1e037fa8ae13566e0dbdc33391.addTo(map_2541798742a605aabb807f7d08416e5f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width

# %%
filter1=terrorist[terrorist['region_txt']== 'Central Asia']
filter2= filter1[filter1['iyear'] >= 2000]
filter3= filter2[filter2['nkill'] >= 10 ] 

ME_terror = filter2.groupby(['longitude', 'latitude']).size().reset_index(name= 'incident_count')

heat_df = ME_terror[['latitude', 'longitude', 'incident_count']].values.tolist()
map_= folium.Map(location= [30,40], zoom_start = 4)
HeatMap(heat_df).add_to(map_)

# %% [markdown]
# <h1>REGION</h1>

# %%
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_19eb686a7916956cb8eb710071132707 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_19eb686a7916956cb8eb710071132707&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_19eb686a7916956cb8eb710071132707 = L.map(
#                 &quot;map_19eb686a7916956cb8eb710071132707&quot;,
#                 {
#                     center: [30.0, 40.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9b30814089556a0f6c183f9906b34a8f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9b30814089556a0f6c183f9906b34a8f.addTo(map_19eb686a7916956cb8eb710071132707);
#
#
#             var heat_map_5272c7c291556e7857c09ce3cf9e45bd = L.heatLayer(
#                 [[31.633333, -8.0, 1.0], [33.59, -7.61, 1.0], [35.391899, 0.138188, 1.0], [36.072919, 1.988153, 1.0], [36.526708, 2.344489, 1.0], [36.46298, 2.81464, 1.0], [36.763763, 3.055413, 3.0], [36.56522, 3.153934, 1.0], [36.562222, 3.594444, 2.0], [36.72398, 3.670848, 2.0], [36.672703, 3.809529, 1.0], [36.919552, 3.891396, 1.0], [36.37489, 3.902, 2.0], [36.716365, 4.049834, 1.0], [34.680833, 4.096944, 1.0], [36.077754, 4.462888, 1.0], [36.28611, 5.60722, 1.0], [36.813267, 5.751706, 1.0], [35.59901, 5.893085, 1.0], [35.55, 6.166667, 1.0], [36.673926, 6.83876, 1.0], [36.866618, 6.900388, 1.0], [35.43811, 7.146648, 1.0], [36.811427, 10.184214, 1.0], [33.819136, 10.855024, 1.0], [32.063988, 12.691492, 1.0], [32.8, 12.9, 1.0], [32.867867, 13.189067, 4.0], [32.407892, 14.622688, 1.0], [31.448914, 15.256008, 1.0], [31.395836, 15.724736, 1.0], [31.197586, 16.586681, 2.0], [32.069286, 20.151144, 7.0], [32.094952, 20.268871, 1.0], [32.42202, 20.451099, 1.0], [32.762238, 22.241188, 2.0], [27.058452, 27.969925, 1.0], [41.106178, 28.689863, 10.0], [30.762296, 29.696268, 1.0], [31.19829, 29.899403, 1.0], [30.787678, 30.999529, 1.0], [30.022924, 31.185192, 1.0], [30.084629, 31.334314, 2.0], [29.831976, 31.337257, 1.0], [31.039309, 31.379664, 1.0], [39.930771, 32.76754, 3.0], [39.798509, 32.805613, 1.0], [31.016779, 33.008587, 1.0], [30.608472, 33.617577, 1.0], [31.080795, 33.638188, 1.0], [30.699335, 33.644714, 1.0], [31.126646, 33.800865, 5.0], [30.886219, 34.076081, 1.0], [31.211645, 34.110425, 1.0], [31.212225, 34.117065, 3.0], [30.169854, 34.173178, 1.0], [31.250196, 34.24128, 1.0], [30.99614, 34.247173, 1.0], [27.915557, 34.329886, 1.0], [28.509136, 34.513634, 1.0], [31.821444, 34.665169, 1.0], [31.970541, 34.791725, 1.0], [32.08297, 34.811886, 3.0], [32.332612, 34.851529, 1.0], [32.325073, 34.854663, 1.0], [29.490095, 34.899447, 1.0], [32.473605, 34.975094, 1.0], [32.793921, 34.990615, 6.0], [32.161864, 35.137217, 1.0], [32.581387, 35.182465, 1.0], [31.771599, 35.2034, 9.0], [38.720489, 35.482597, 1.0], [33.861984, 35.489986, 2.0], [33.843471, 35.498738, 2.0], [33.888523, 35.503513, 3.0], [35.528404, 35.79232, 3.0], [33.126944, 35.825796, 1.0], [33.280891, 35.829319, 1.0], [34.438062, 35.830744, 2.0], [34.438094, 35.830837, 2.0], [34.443955, 35.854032, 1.0], [34.896351, 35.886443, 2.0], [34.896112, 35.886553, 1.0], [34.895928, 35.886652, 2.0], [35.361572, 35.927155, 4.0], [31.950001, 35.933331, 3.0], [32.835648, 35.970169, 1.0], [32.711067, 36.026836, 1.0], [32.674366, 36.056892, 1.0], [32.962402, 36.076488, 1.0], [33.436207, 36.080795, 1.0], [32.622334, 36.103756, 3.0], [33.622993, 36.11203, 1.0], [35.688751, 36.135868, 1.0], [32.834137, 36.156742, 1.0], [34.715336, 36.255295, 1.0], [33.484396, 36.268508, 1.0], [33.515244, 36.292084, 34.0], [33.435532, 36.295208, 1.0], [33.5111, 36.3064, 1.0], [33.60722, 36.314327, 1.0], [32.568889, 36.315278, 1.0], [35.813396, 36.319939, 1.0], [35.413296, 36.33012, 1.0], [33.446476, 36.334499, 6.0], [35.290483, 36.345111, 1.0], [33.488998, 36.346882, 4.0], [33.561504, 36.368763, 2.0], [33.484444, 36.377289, 1.0], [33.755295, 36.388622, 1.0], [33.527649, 36.392296, 1.0], [32.696985, 36.398428, 1.0], [35.713863, 36.525666, 1.0], [36.264221, 36.565708, 3.0], [32.709763, 36.567642, 1.0], [34.951523, 36.581963, 1.0], [35.813972, 36.609917, 2.0], [35.928802, 36.631451, 5.0], [35.933333, 36.633333, 1.0], [35.925894, 36.6519, 1.0], [36.313854, 36.660312, 1.0], [35.855245, 36.671186, 1.0], [36.01313, 36.673443, 1.0], [35.647797, 36.675259, 2.0], [35.990086, 36.677223, 1.0], [36.310444, 36.689156, 3.0], [33.6432, 36.690445, 1.0], [35.982761, 36.704647, 2.0], [34.717705, 36.722824, 21.0], [33.611455, 36.75523, 1.0], [35.129181, 36.760738, 2.0], [36.213078, 36.769512, 1.0], [34.097931, 36.770164, 1.0], [35.868511, 36.804665, 1.0], [35.068056, 36.888889, 1.0], [36.377281, 36.993607, 1.0], [35.993954, 36.998383,

# %%
terrorist['region_txt'].unique()
# Out:
# array(['Central America & Caribbean', 'North America', 'Southeast Asia',
#        'Western Europe', 'East Asia', 'South America', 'Eastern Europe',
#        'Sub-Saharan Africa', 'Middle East & North Africa',
#        'Australasia & Oceania', 'South Asia', 'Central Asia'],
#       dtype=object)

# %% [markdown]
# <h1 style='background:gray;'>LIBRAIRES</h1>

# %%
terrorist = pd.read_csv("Datasets//Global_terrorist.csv", encoding='ISO-8859-1')
terrorist.head()
# Out:
# /var/folders/4x/g0l0pk411w91t3wj50qy02qr0000gn/T/ipykernel_1043/2446199330.py:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   terrorist = pd.read_csv("Datasets//Global_terrorist.csv", encoding='ISO-8859-1')
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %%
terrorist
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# 0            58  Dominican Republic       2  ...      NaN
# 1           130              Mexico       1  ...      NaN
# 2           160         Philippines       5  ...      NaN
# 3            78              Greece       8  ...      NaN
# 4           101               Japan       4  ...      NaN
# ...         ...                 ...     ...  ...      ...
# 181686      182             Somalia      11  ...      NaN
# 181687      200               Syria      10  ...      NaN
# 181688      160         Philippines       5  ...      NaN
# 181689       92               India       6  ...      NaN
# 181690      160         Philippines       5  ...      NaN
#
#                                                    scite1  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# 181688  "Maguindanao clashes trap tribe members," Phil...
# 181689  "Trader escapes grenade attack in Imphal," Bus...
# 181690  "Security tightened in Cotabato following IED ...
#
#                                                    scite2  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Highlights: Somalia Daily Media Highlights 2 ...
# 181687  "Two Russian soldiers killed at Hmeymim base i...
# 181688                                                NaN
# 181689                                                NaN
# 181690  "Security tightened in Cotabato City," Manila ...
#
#                                                    scite3  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Highlights: Somalia Daily Media Highlights 1 ...
# 181687  "Two Russian servicemen killed in Syria mortar...
# 181688                                                NaN
# 181689                                                NaN
# 181690                                                NaN
#
#                         dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0                           PGIS        0         0        0       0      NaN
# 1                           PGIS        0         1        1       1      NaN
# 2                           PGIS       -9        -9        1       1      NaN
# 3                           PGIS       -9        -9        1       1      NaN
# 4                           PGIS       -9        -9        1       1      NaN
# ...                          ...      ...       ...      ...     ...      ...
# 181686  START Primary Collection        0         0        0       0      NaN
# 181687  START Primary Collection       -9        -9        1       1      NaN
# 181688  START Primary Collection        0         0        0       0      NaN
# 181689  START Primary Collection       -9        -9        0      -9      NaN
# 181690  START Primary Collection       -9        -9        0      -9      NaN
#
# [181691 rows x 135 columns]

# %%
terrorist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
terrorist.columns.to_list()
# Out:
# ['eventid',
#  'iyear',
#  'imonth',
#  'iday',
#  'approxdate',
#  'extended',
#  'resolution',
#  'country',
#  'country_txt',
#  'region',
#  'region_txt',
#  'provstate',
#  'city',
#  'latitude',
#  'longitude',
#  'specificity',
#  'vicinity',
#  'location',
#  'summary',
#  'crit1',
#  'crit2',
#  'crit3',
#  'doubtterr',
#  'alternative',
#  'alternative_txt',
#  'multiple',
#  'success',
#  'suicide',
#  'attacktype1',
#  'attacktype1_txt',
#  'attacktype2',
#  'attacktype2_txt',
#  'attacktype3',
#  'attacktype3_txt',
#  'targtype1',
#  'targtype1_txt',
#  'targsubtype1',
#  'targsubtype1_txt',
#  'corp1',
#  'target1',
#  'natlty1',
#  'natlty1_txt',
#  'targtype2',
#  'targtype2_txt',
#  'targsubtype2',
#  'targsubtype2_txt',
#  'corp2',
#  'target2',
#  'natlty2',
#  'natlty2_txt',
#  'targtype3',
#  'targtype3_txt',
#  'targsubtype3',
#  'targsubtype3_txt',
#  'corp3',
#  'target3',
#  'natlty3',
#  'natlty3_txt',
#  'gname',
#  'gsubname',
#  'gname2',
#  'gsubname2',
#  'gname3',
#  'gsubname3',
#  'motive',
#  'guncertain1',
#  'guncertain2',
#  'guncertain3',
#  'individual',
#  'nperps',
#  'nperpcap',
#  'claimed',
#  'claimmode',
#  'claimmode_txt',
#  'claim2',
#  'claimmode2',
#  'claimmode2_txt',
#  'claim3',
#  'claimmode3',
#  'claimmode3_txt',
#  'compclaim',
#  'weaptype1',
#  'weaptype1_txt',
#  'weapsubtype1',
#  'weapsubtype1_txt',
#  'weaptype2',
#  'weaptype2_txt',
#  'weapsubtype2',
#  'weapsubtype2_txt',
#  'weaptype3',
#  'weaptype3_txt',
#  'weapsubtype3',
#  'weapsubtype3_txt',
#  'weaptype4',
#  'weaptype4_txt',
#  'weapsubtype4',
#  'weapsubtype4_txt',
#  'weapdetail',
#  'nkill',
#  'nkillus',
#  'nkillter',
#  'nwound',
#  'nwoundus',
#  'nwoundte',
#  'property',
#  'propextent',
#  'propextent_txt',
#  'propvalue',
#  'propcomment',
#  'ishostkid',
#  'nhostkid',
#  'nhostkidus',
#  'nhours',
#  'ndays',
#  'divert',
#  'kidhijcountry',
#  'ransom',
#  'ransomamt',
#  'ransomamtus',
#  'ransompaid',
#  'ransompaidus',
#  'ransomnote',
#  'hostkidoutcome',
#  'hostkidoutcome_txt',
#  'nreleased',
#  'addnotes',
#  'scite1',
#  'scite2',
#  'scite3',
#  'dbsource',
#  'INT_LOG',
#  'INT_IDEO',
#  'INT_MISC',
#  'INT_ANY',
#  'related']

# %%
terrorist.astype
# Out:
# <bound method NDFrame.astype of              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# 0            58  Dominican Republic       2  ...      NaN
# 1           130              Mexico       1  ...      NaN
# 2           160         Philippines       5  ...      NaN
# 3            78              Greece       8  ...      NaN
# 4           101               Japan       4  ...      NaN
# ...         ...                 ...     ...  ...      ...
# 181686      182             Somalia      11  ...      NaN
# 181687      200               Syria      10  ...      NaN
# 181688      160         Philippines       5  ...      NaN
# 181689       92               India       6  ...      NaN
# 181690      160         Philippines       5  ...      NaN
#
#                                                    scite1  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# 181688  "Maguindanao clashes trap tribe members," Phil...
# 181689  "Trader escapes grenade attack in Imphal," Bus...
# 181690  "Security tightened in Cotabato following IED ...
#
#                                                    scite2  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Highlights: Somalia Daily Media Highlights 2 ...
# 181687  "Two Russian soldiers killed at Hmeymim base i...
# 181688                                                NaN
# 181689                                                NaN
# 181690  "Security tightened in Cotabato City," Manila ...
#
#                                                    scite3  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Highlights: Somalia Daily Media Highlights 1 ...
# 181687  "Two Russian servicemen killed in Syria mortar...
# 181688                                                NaN
# 181689                                                NaN
# 181690                                                NaN
#
#                         dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0                           PGIS        0         0        0       0      NaN
# 1                           PGIS        0         1        1       1      NaN
# 2                           PGIS       -9        -9        1       1      NaN
# 3                           PGIS       -9        -9        1       1      NaN
# 4                           PGIS       -9        -9        1       1      NaN
# ...                          ...      ...       ...      ...     ...      ...
# 181686  START Primary Collection        0         0        0       0      NaN
# 181687  START Primary Collection       -9        -9        1       1      NaN
# 181688  START Primary Collection        0         0        0       0      NaN
# 181689  START Primary Collection       -9        -9        0      -9      NaN
# 181690  START Primary Collection       -9        -9        0      -9      NaN
#
# [181691 rows x 135 columns]>

# %%
terrorist.isnull()
terrorist.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %% [markdown]
# <h1><b>Insight 6: </b>Country Analysis on India</h1>

# %%
India = terror[terror.country_txt=='India']
India.head(5)
# Out:
#       iyear country_txt  region_txt        city  success    attacktype1_txt  \
# 1186   1972       India  South Asia   New Delhi        1          Hijacking
# 2764   1975       India  South Asia  Samastipur        1  Bombing/Explosion
# 3857   1976       India  South Asia   New Delhi        1  Bombing/Explosion
# 5327   1977       India  South Asia      Bombay        1          Hijacking
# 7337   1979       India  South Asia     Unknown        1      Armed Assault
#
#              targtype1_txt                                   targsubtype1_txt  \
# 1186   Airports & Aircraft                       Aircraft (not at an airport)
# 2764  Government (General)  Government Personnel (excluding police, military)
# 3857   Airports & Aircraft                                            Airport
# 5327   Airports & Aircraft                       Aircraft (not at an airport)
# 7337                Police     Police Patrol (including vehicles and convoys)
#
#                                     target1 natlty1_txt  \
# 1186                                  B-747     Germany
# 2764  Lalit Narayan Mishra and a legislator       India
# 3857                      New Delhi airport       India
# 5327                                   DC-8       Japan
# 7337                                 patrol       India
#
#                         gname   motive  nkill  property
# 1186             Palestinians      NaN    0.0         0
# 2764             Ananda Marga  Unknown    4.0         0
# 3857                  Unknown      NaN    0.0         1
# 5327  Japanese Red Army (JRA)      NaN    0.0         0
# 7337              Naga People      NaN    NaN         1

# %%
India.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11960 entries, 1186 to 181689
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   iyear             11960 non-null  int64
#  1   country_txt       11960 non-null  object
#  2   region_txt        11960 non-null  object
#  3   city              11960 non-null  object
#  4   success           11960 non-null  int64
#  5   attacktype1_txt   11960 non-null  object
#  6   targtype1_txt     11960 non-null  object
#  7   targsubtype1_txt  11113 non-null  object
#  8   target1           11918 non-null  object
#  9   natlty1_txt       11934 non-null  object
#  10  gname             11960 non-null  object
#  11  motive            5685 non-null   object
#  12  nkill             11740 non-null  float64
#  13  property          11960 non-null  int64
# dtypes: float64(1), int64(3), object(10)
# memory usage: 1.4+ MB

# %%
India.success.value_counts()
# Out:
# success
# 1    10280
# 0     1680
# Name: count, dtype: int64

# %% [markdown]
# <h1><b>Insight 7:</b> 10280 successful terror strike has taken place in india while 1680 attempts failed fron 1970-2017</h1>

# %%
India.iyear.value_counts().index.sort_values()
# Out:
# Index([1972, 1975, 1976, 1977, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986,
#        1987, 1988, 1989, 1990, 1991, 1992, 1994, 1995, 1996, 1997, 1998, 1999,
#        2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017],
#       dtype='int64', name='iyear')

# %%
plt.figure(figsize=(20,6))
sns.barplot(y=India.iyear.value_counts().values,x=India.iyear.value_counts().index)
plt.title('Common target types')
plt.xlabel('Count')
plt.ylabel('Target')
# Out:
# Text(0, 0.5, 'Target')

# %%
India.city.value_counts().head(11)
# Out:
# city
# Srinagar            658
# Unknown             624
# Imphal              426
# New Delhi           157
# Amritsar            138
# Sopore              102
# Guwahati             77
# Ludhiana             77
# Anantnag             76
# Jammu                57
# Latehar district     55
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,3))
sns.barplot(x=India.city.value_counts().head(11).values,y=India.city.value_counts().head(11).index)
plt.title('Top terror stricken cities in India since 1970')
plt.xlabel('City')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
India[India.iyear>=2008].city.value_counts().head(10)
# Out:
# city
# Imphal                     388
# Srinagar                   108
# Unknown                    103
# Sopore                      68
# Latehar district            54
# Bijapur district            50
# Sukma district              49
# West Midnapore district     41
# Malkangiri district         40
# Dantewada district          35
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,3))
sns.barplot(x=India[India.iyear>=2008].city.value_counts().head(10).values,y=India[India.iyear>=2008].city.value_counts().head(10).index)
plt.title('Top terror stricken cities in India since 2008')
plt.ylabel('Count')
plt.xlabel('City')
# Out:
# Text(0.5, 0, 'City')

# %%
plt.figure(figsize=(5,3))
sns.barplot(x=India[India.iyear>=2008].city.value_counts().head(10).values,y=India[India.iyear>=2008].city.value_counts().head(10).index)
plt.title('Type of attack employed')
plt.xlabel('Count')
plt.ylabel('Strike mode')
# Out:
# Text(0, 0.5, 'Strike mode')

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=India.targtype1_txt.value_counts().values,y=India.targtype1_txt.value_counts().index)
plt.title('Common target types in India')
plt.xlabel('Count')
plt.ylabel('Target')
# Out:
# Text(0, 0.5, 'Target')

# %%
plt.figure(figsize=(10, 5))
sns.barplot(
    x=India.targsubtype1_txt.value_counts().head(10).values,
    y=India.targsubtype1_txt.value_counts().head(10).index,)
plt.title('Common Target Subtypes in India')
plt.xlabel('Count')
plt.ylabel('Target Subtype')
plt.show()

# %%
India.gname.value_counts().head(25)[1:]
# Out:
# gname
# Communist Party of India - Maoist (CPI-Maoist)                  1877
# Maoists                                                         1396
# Sikh Extremists                                                  710
# United Liberation Front of Assam (ULFA)                          357
# Hizbul Mujahideen (HM)                                           199
# Lashkar-e-Taiba (LeT)                                            187
# National Democratic Front of Bodoland (NDFB)                     174
# Garo National Liberation Army                                    166
# Muslim Separatists                                               118
# People's War Group (PWG)                                          97
# National Socialist Council of Nagaland-Isak-Muivah (NSCN-IM)      89
# People's Liberation Army (India)                                  88
# Bodo Militants                                                    87
# Muslim Militants                                                  87
# National Liberation Front of Tripura (NLFT)                       78
# Separatists                                                       77
# Kashmiri extremists                                               77
# Gorkha Janmukti Morcha (GJM)                                      67
# People's Liberation Front of India                                67
# Naxalites                                                         66
# Gurkha National Liberation Front (GNLF)                           59
# National Socialist Council of Nagaland-Khaplang (NSCN-K)          57
# Jammu and Kashmir Liberation Front                                53
# Indian Mujahideen                                                 52
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 5))
sns.barplot(
    x=India.gname.value_counts().head(11)[1:].values,
    y=India.gname.value_counts().head(11)[1:].index,)
plt.title('Attack by Terrorist Organizations in India')
plt.xlabel('Count')
plt.ylabel('Terrorist organization')
plt.show()

# %% [markdown]
# <h1><b>Insight 8:</b> The CP(Maoist) has carried the largest number of terror attacks in india since 1970 followed by Sikh extremists and ULFA</h1>

# %%
plt.figure(figsize=(10,6))
sns.barplot(
            x=India[India.iyear>=2007].gname.value_counts().head(11)[1:].values,
            y=India[India.iyear>=2007].gname.value_counts().head(11)[1:].index
           )
plt.title('Attack by Terrorist Organizations in India')
plt.xlabel('Count')
plt.ylabel('Terrorist organization')
# Out:
# Text(0, 0.5, 'Terrorist organization')

# %% [markdown]
# <h1><b>Insight 9:</b> In the last deacade has seen a fall of a particular terror group namely 'Sikh Extremists'</h1>

# %% [markdown]
# <h1>Insight 10</h1>

# %%
# Getting the requisite columns
terror = terrorist[['iyear','country_txt','region_txt','city','success','attacktype1_txt','targtype1_txt','targsubtype1_txt','target1','natlty1_txt','gname','motive','nkill','property']]

# %%
terror.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   iyear             181691 non-null  int64
#  1   country_txt       181691 non-null  object
#  2   region_txt        181691 non-null  object
#  3   city              181256 non-null  object
#  4   success           181691 non-null  int64
#  5   attacktype1_txt   181691 non-null  object
#  6   targtype1_txt     181691 non-null  object
#  7   targsubtype1_txt  171318 non-null  object
#  8   target1           181053 non-null  object
#  9   natlty1_txt       180132 non-null  object
#  10  gname             181691 non-null  object
#  11  motive            50561 non-null   object
#  12  nkill             171378 non-null  float64
#  13  property          181691 non-null  int64
# dtypes: float64(1), int64(3), object(10)
# memory usage: 19.4+ MB

# %%
terror.country_txt.nunique()
# Out:
# 205

# %%
terror.region_txt.value_counts()
# Out:
# region_txt
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Central Asia                     563
# Australasia & Oceania            282
# Name: count, dtype: int64

# %%
# Ploting the regionwise reported terror
plt.figure(figsize=(22,10))
plt.bar(x=terror.region_txt.value_counts().index,height=terror.region_txt.value_counts().values)
plt.title('Region')
plt.xlabel('Countries')
plt.ylabel('No. of terrorist activities')
# Out:
# Text(0, 0.5, 'No. of terrorist activities')

# %%
terror.country_txt.value_counts().tail(30)
# Out:
# country_txt
# Malawi                            5
# Grenada                           5
# Western Sahara                    5
# Bahamas                           5
# Montenegro                        5
# Comoros                           5
# Iceland                           4
# Solomon Islands                   4
# People's Republic of the Congo    4
# Dominica                          3
# French Polynesia                  3
# Gambia                            3
# Barbados                          3
# South Yemen                       2
# St. Kitts and Nevis               2
# Turkmenistan                      2
# Vanuatu                           2
# Seychelles                        2
# Mauritius                         2
# Equatorial Guinea                 2
# Andorra                           1
# South Vietnam                     1
# Falkland Islands                  1
# Vatican City                      1
# New Hebrides                      1
# Antigua and Barbuda               1
# North Korea                       1
# Wallis and Futuna                 1
# St. Lucia                         1
# International                     1
# Name: count, dtype: int64

# %%
terror[terror.country_txt=='International']
# Out:
#        iyear    country_txt                  region_txt          city  \
# 74658   2002  International  Middle East & North Africa  Gulf of Aden
#
#        success    attacktype1_txt targtype1_txt targsubtype1_txt  \
# 74658        1  Bombing/Explosion      Maritime       Oil Tanker
#
#                    target1 natlty1_txt     gname  \
# 74658  Tanker ship Limberg      France  Al-Qaida
#
#                                                   motive  nkill  property
# 74658  Osama Bin Ladin stated that the attack was "re...    1.0         1

# %%
terror.country_txt.value_counts().head(10)
# Out:
# country_txt
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: count, dtype: int64

# %%
plt.figure(figsize=(22,10))
plt.bar(x=terror.country_txt.value_counts().head(10).index,height=terror.country_txt.value_counts().head(10).values)
plt.title('Top 10 countries of terror incidences from 1970-2017')
plt.xlabel('Countries')
plt.ylabel('No. of terrorist activities')
# Out:
# Text(0, 0.5, 'No. of terrorist activities')

# %%
terror.gname.value_counts().head(11)[1:]
# Out:
# gname
# Taliban                                             7478
# Islamic State of Iraq and the Levant (ISIL)         5613
# Shining Path (SL)                                   4555
# Farabundo Marti National Liberation Front (FMLN)    3351
# Al-Shabaab                                          3288
# New People's Army (NPA)                             2772
# Irish Republican Army (IRA)                         2671
# Revolutionary Armed Forces of Colombia (FARC)       2487
# Boko Haram                                          2418
# Kurdistan Workers' Party (PKK)                      2310
# Name: count, dtype: int64

# %%
sns.barplot(x=terror.gname.value_counts().head(11)[1:].values,y=terror.gname.value_counts().head(11)[1:].index)
plt.title('Attacks by Terrorist Organizations')
plt.xlabel('Count')
plt.ylabel('Terrorist organization')
# Out:
# Text(0, 0.5, 'Terrorist organization')

# %%
terror.attacktype1_txt.value_counts()
# Out:
# attacktype1_txt
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: count, dtype: int64

# %%
sns.barplot(x=terror.attacktype1_txt.value_counts().values,y=terror.attacktype1_txt.value_counts().index)
plt.title('Types of attack employed')
plt.xlabel('Count')
plt.ylabel('Strie mode')
# Out:
# Text(0, 0.5, 'Strie mode')

# %%
terror.targtype1_txt.value_counts()
# Out:
# targtype1_txt
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Government (Diplomatic)            3573
# Terrorists/Non-State Militia       3039
# Journalists & Media                2948
# Violent Political Party            1866
# Airports & Aircraft                1343
# Telecommunication                  1009
# NGO                                 970
# Tourists                            440
# Maritime                            351
# Food or Water Supply                317
# Abortion Related                    263
# Other                               137
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=terror.targtype1_txt.value_counts().values,y=terror.targtype1_txt.value_counts().index)
plt.title('Common target types')
plt.xlabel('Count')
plt.ylabel('Target')
# Out:
# Text(0, 0.5, 'Target')

# %% [markdown]
# <h2><b>Insights:</b> Private citizens & properly are targetted the most followed by military police, government & businesses</h2>
